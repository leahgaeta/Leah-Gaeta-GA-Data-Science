# %%
import pandas as pd
import json

data = pd.read_csv("../../../lesson-13/code/dataset/stumbleupon.tsv", sep='\t')
data['title'] = data.boilerplate.map(lambda x: json.loads(x).get('title', ''))
data['body'] = data.boilerplate.map(lambda x: json.loads(x).get('body', ''))
data.head()
# Out:
#                                                  url  urlid  \
# 0  http://www.bloomberg.com/news/2010-12-23/ibm-p...   4042
# 1  http://www.popsci.com/technology/article/2012-...   8471
# 2  http://www.menshealth.com/health/flu-fighting-...   1164
# 3  http://www.dumblittleman.com/2007/12/10-foolpr...   6684
# 4  http://bleacherreport.com/articles/1205138-the...   9006
#
#                                          boilerplate alchemy_category  \
# 0  {"title":"IBM Sees Holographic Calls Air Breat...         business
# 1  {"title":"The Fully Electronic Futuristic Star...       recreation
# 2  {"title":"Fruits that Fight the Flu fruits tha...           health
# 3  {"title":"10 Foolproof Tips for Better Sleep "...           health
# 4  {"title":"The 50 Coolest Jerseys You Didn t Kn...           sports
#
#   alchemy_category_score  avglinksize  commonlinkratio_1  commonlinkratio_2  \
# 0               0.789131     2.055556           0.676471           0.205882
# 1               0.574147     3.677966           0.508021           0.288770
# 2               0.996526     2.382883           0.562016           0.321705
# 3               0.801248     1.543103           0.400000           0.100000
# 4               0.719157     2.676471           0.500000           0.222222
#
#    commonlinkratio_3  commonlinkratio_4  \
# 0           0.047059           0.023529
# 1           0.213904           0.144385
# 2           0.120155           0.042636
# 3           0.016667           0.000000
# 4           0.123457           0.043210
#
#                          ...                          linkwordscore  \
# 0                        ...                                     24
# 1                        ...                                     40
# 2                        ...                                     55
# 3                        ...                                     24
# 4                        ...                                     14
#
#    news_front_page  non_markup_alphanum_characters  numberOfLinks  \
# 0                0                            5424            170
# 1                0                            4973            187
# 2                0                            2240            258
# 3                0                            2737            120
# 4                0                           12032            162
#
#    numwords_in_url  parametrizedLinkRatio  spelling_errors_ratio label  \
# 0                8               0.152941               0.079130     0
# 1                9               0.181818               0.125448     1
# 2               11               0.166667               0.057613     1
# 3                5               0.041667               0.100858     1
# 4               10               0.098765               0.082569     0
#
#                                                title  \
# 0  IBM Sees Holographic Calls Air Breathing Batte...
# 1  The Fully Electronic Futuristic Starting Gun T...
# 2  Fruits that Fight the Flu fruits that fight th...
# 3                10 Foolproof Tips for Better Sleep
# 4  The 50 Coolest Jerseys You Didn t Know Existed...
#
#                                                 body
# 0  A sign stands outside the International Busine...
# 1  And that can be carried on a plane without the...
# 2  Apples The most popular source of antioxidants...
# 3  There was a period in my life when I had a lot...
# 4  Jersey sales is a curious business Whether you...
#
# [5 rows x 29 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

bodies = data['body'].dropna().copy() #or fillna('')
vectorizer = CountVectorizer(max_features=1000, binary = False, stop_words='english')

# %%
X = vectorizer.fit_transform(bodies)

# %%
id2word = dict(enumerate(vectorizer.get_feature_names()))

# %%
id2word
# Out:
# {0: u'00',
#  1: u'000',
#  2: u'08',
#  3: u'09',
#  4: u'10',
#  5: u'100',
#  6: u'11',
#  7: u'12',
#  8: u'13',
#  9: u'14',
#  10: u'15',
#  11: u'16',
#  12: u'17',
#  13: u'18',
#  14: u'19',
#  15: u'20',
#  16: u'2005',
#  17: u'2006',
#  18: u'2007',
#  19: u'2008',
#  20: u'2009',
#  21: u'2010',
#  22: u'2011',
#  23: u'2012',
#  24: u'21',
#  25: u'22',
#  26: u'23',
#  27: u'24',
#  28: u'25',
#  29: u'26',
#  30: u'27',
#  31: u'28',
#  32: u'29',
#  33: u'30',
#  34: u'31',
#  35: u'35',
#  36: u'350',
#  37: u'40',
#  38: u'45',
#  39: u'50',
#  40: u'60',
#  41: u'ability',
#  42: u'able',
#  43: u'according',
#  44: u'actually',
#  45: u'ad',
#  46: u'add',
#  47: u'added',
#  48: u'adding',
#  49: u'addition',
#  50: u'additional',
#  51: u'age',
#  52: u'ago',
#  53: u'air',
#  54: u'alcohol',
#  55: u'allow',
#  56: u'amazing',
#  57: u'america',
#  58: u'american',
#  59: u'app',
#  60: u'apple',
#  61: u'apples',
#  62: u'april',
#  63: u'area',
#  64: u'aren',
#  65: u'art',
#  66: u'article',
#  67: u'aside',
#  68: u'ask',
#  69: u'asked',
#  70: u'athletes',
#  71: u'attention',
#  72: u'august',
#  73: u'author',
#  74: u'available',
#  75: u'average',
#  76: u'avocado',
#  77: u'avoid',
#  78: u'away',
#  79: u'awesome',
#  80: u'baby',
#  81: u'background',
#  82: u'bacon',
#  83: u'bad',
#  84: u'bag',
#  85: u'bake',
#  86: u'baked',
#  87: u'baking',
#  88: u'ball',
#  89: u'balls',
#  90: u'banana',
#  91: u'bar',
#  92: u'bars',
#  93: u'base',
#  94: u'based',
#  95: u'basic',
#  96: u'basil',
#  97: u'batter',
#  98: u'bean',
#  99: u'beans',
#  100: u'beat',
#  101: u'beautiful',
#  102: u'beauty',
#  103: u'beef',
#  104: u'beer',
#  105: u'begin',
#  106: u'believe',
#  107: u'benefits',
#  108: u'best',
#  109: u'better',
#  110: u'big',
#  111: u'bit',
#  112: u'black',
#  113: u'blend',
#  114: u'blog',
#  115: u'blood',
#  116: u'blue',
#  117: u'board',
#  118: u'body',
#  119: u'boil',
#  120: u'book',
#  121: u'bought',
#  122: u'bowl',
#  123: u'box',
#  124: u'brain',
#  125: u'bread',
#  126: u'break',
#  127: u'breakfast',
#  128: u'breast',
#  129: u'bring',
#  130: u'broccoli',
#  131: u'brown',
#  132: u'brownies',
#  133: u'business',
#  134: u'butter',
#  135: u'buy',
#  136: u'buzz',
#  137: u'cake',
#  138: u'cakes',
#  139: u'california',
#  140: u'called',
#  141: u'calories',
#  142: u'came',
#  143: u'campaign',
#  144: u'cancer',
#  145: u'candy',
#  146: u'car',
#  147: u'caramel',
#  148: u'care',
#  149: u'case',
#  150: u'category',
#  151: u'cause',
#  152: u'cells',
#  153: u'center',
#  154: u'certain',
#  155: u'chance',
#  156: u'change',
#  157: u'check',
#  158: u'cheddar',
#  159: u'cheese',
#  160: u'cheesecake',
#  161: u'chef',
#  162: u'chicken',
#  163: u'child',
#  164: u'children',
#  165: u'chili',
#  166: u'chinese',
#  167: u'chip',
#  168: u'chips',
#  169: u'chocolate',
#  170: u'choice',
#  171: u'cholesterol',
#  172: u'choose',
#  173: u'chopped',
#  174: u'christmas',
#  175: u'cinnamon',
#  176: u'city',
#  177: u'class',
#  178: u'classic',
#  179: u'clean',
#  180: u'clear',
#  181: u'click',
#  182: u'close',
#  183: u'clothing',
#  184: u'cloves',
#  185: u'coat',
#  186: u'cocoa',
#  187: u'coconut',
#  188: u'coffee',
#  189: u'cold',
#  190: u'collection',
#  191: u'college',
#  192: u'color',
#  193: u'com',
#  194: u'combination',
#  195: u'combine',
#  196: u'combined',
#  197: u'come',
#  198: u'comes',
#  199: u'coming',
#  200: u'comment',
#  201: u'comments',
#  202: u'common',
#  203: u'community',
#  204: u'company',
#  205: u'complete',
#  206: u'completely',
#  207: u'computer',
#  208: u'concept',
#  209: u'container',
#  210: u'content',
#  211: u'continue',
#  212: u'control',
#  213: u'cook',
#  214: u'cooked',
#  215: u'cookie',
#  216: u'cookies',
#  217: u'cooking',
#  218: u'cool',
#  219: u'corn',
#  220: u'cost',
#  221: u'couldn',
#  222: u'country',
#  223: u'couple',
#  224: u'course',
#  225: u'cover',
#  226: u'covered',
#  227: u'cream',
#  228: u'creamy',
#  229: u'create',
#  230: u'created',
#  231: u'crisp',
#  232: u'crumbs',
#  233: u'crust',
#  234: u'culture',
#  235: u'cup',
#  236: u'cupcake',
#  237: u'cupcakes',
#  238: u'cups',
#  239: u'cut',
#  240: u'daily',
#  241: u'damascus',
#  242: u'dark',
#  243: u'data',
#  244: u'date',
#  245: u'day',
#  246: u'days',
#  247: u'deal',
#  248: u'death',
#  249: u'december',
#  250: u'decided',
#  251: u'deep',
#  252: u'definitely',
#  253: u'degrees',
#  254: u'delicious',
#  255: u'design',
#  256: u'designed',
#  257: u'dessert',
#  258: u'desserts',
#  259: u'did',
#  260: u'didn',
#  261: u'diet',
#  262: u'different',
#  263: u'dinner',
#  264: u'dip',
#  265: u'directions',
#  266: u'disease',
#  267: u'dish',
#  268: u'dishes',
#  269: u'display',
#  270: u'div',
#  271: u'does',
#  272: u'doesn',
#  273: u'dog',
#  274: u'doing',
#  275: u'don',
#  276: u'double',
#  277: u'dough',
#  278: u'dr',
#  279: u'dress',
#  280: u'dried',
#  281: u'drink',
#  282: u'drinking',
#  283: u'drop',
#  284: u'drug',
#  285: u'dry',
#  286: u'early',
#  287: u'easier',
#  288: u'easily',
#  289: u'easy',
#  290: u'eat',
#  291: u'eating',
#  292: u'edges',
#  293: u'effect',
#  294: u'effects',
#  295: u'egg',
#  296: u'eggs',
#  297: u'electric',
#  298: u'email',
#  299: u'end',
#  300: u'energy',
#  301: u'enjoy',
#  302: u'entire',
#  303: u'especially',
#  304: u'evenly',
#  305: u'event',
#  306: u'exactly',
#  307: u'example',
#  308: u'exercise',
#  309: u'experience',
#  310: u'extra',
#  311: u'extract',
#  312: u'eye',
#  313: u'eyes',
#  314: u'face',
#  315: u'facebook',
#  316: u'fact',
#  317: u'fall',
#  318: u'false',
#  319: u'family',
#  320: u'fan',
#  321: u'fans',
#  322: u'far',
#  323: u'fashion',
#  324: u'fast',
#  325: u'fat',
#  326: u'favorite',
#  327: u'features',
#  328: u'february',
#  329: u'feel',
#  330: u'feeling',
#  331: u'feet',
#  332: u'fiber',
#  333: u'field',
#  334: u'filled',
#  335: u'filling',
#  336: u'finally',
#  337: u'fine',
#  338: u'firm',
#  339: u'fish',
#  340: u'fit',
#  341: u'fitness',
#  342: u'flashvars',
#  343: u'flat',
#  344: u'flavor',
#  345: u'flavors',
#  346: u'flour',
#  347: u'foil',
#  348: u'fold',
#  349: u'follow',
#  350: u'following',
#  351: u'food',
#  352: u'foods',
#  353: u'football',
#  354: u'form',
#  355: u'free',
#  356: u'freezer',
#  357: u'french',
#  358: u'fresh',
#  359: u'fridge',
#  360: u'fried',
#  361: u'friend',
#  362: u'friends',
#  363: u'frosting',
#  364: u'frozen',
#  365: u'fruit',
#  366: u'fruits',
#  367: u'fry',
#  368: u'fun',
#  369: u'function',
#  370: u'funny',
#  371: u'future',
#  372: u'game',
#  373: u'games',
#  374: u'garlic',
#  375: u'gently',
#  376: u'gets',
#  377: u'getting',
#  378: u'ginger',
#  379: u'girl',
#  380: u'given',
#  381: u'gives',
#  382: u'glass',
#  383: u'goes',
#  384: u'going',
#  385: u'gold',
#  386: u'golden',
#  387: u'good',
#  388: u'google',
#  389: u'got',
#  390: u'grated',
#  391: u'great',
#  392: u'green',
#  393: u'grill',
#  394: u'grilled',
#  395: u'ground',
#  396: u'group',
#  397: u'guide',
#  398: u'guy',
#  399: u'hair',
#  400: u'half',
#  401: u'hand',
#  402: u'hands',
#  403: u'happy',
#  404: u'hard',
#  405: u'having',
#  406: u'head',
#  407: u'health',
#  408: u'healthy',
#  409: u'heart',
#  410: u'heat',
#  411: u'heavy',
#  412: u'height',
#  413: u'help',
#  414: u'helps',
#  415: u'herbs',
#  416: u'high',
#  417: u'history',
#  418: u'hit',
#  419: u'hold',
#  420: u'holiday',
#  421: u'home',
#  422: u'homemade',
#  423: u'honey',
#  424: u'hope',
#  425: u'hot',
#  426: u'hour',
#  427: u'hours',
#  428: u'house',
#  429: u'href',
#  430: u'http',
#  431: u'huge',
#  432: u'human',
#  433: u'ice',
#  434: u'idea',
#  435: u'ideas',
#  436: u'image',
#  437: u'images',
#  438: u'immediately',
#  439: u'important',
#  440: u'improve',
#  441: u'inch',
#  442: u'inches',
#  443: u'include',
#  444: u'including',
#  445: u'increase',
#  446: u'industry',
#  447: u'information',
#  448: u'ingredients',
#  449: u'inside',
#  450: u'inspired',
#  451: u'instead',
#  452: u'instructions',
#  453: u'interesting',
#  454: u'international',
#  455: u'internet',
#  456: u'iphone',
#  457: u'isn',
#  458: u'issue',
#  459: u'italian',
#  460: u'items',
#  461: u'january',
#  462: u'job',
#  463: u'jpg',
#  464: u'juice',
#  465: u'july',
#  466: u'june',
#  467: u'just',
#  468: u'key',
#  469: u'kids',
#  470: u'kind',
#  471: u'kitchen',
#  472: u'knew',
#  473: u'knife',
#  474: u'know',
#  475: u'known',
#  476: u'la',
#  477: u'large',
#  478: u'later',
#  479: u'latest',
#  480: u'layer',
#  481: u'lead',
#  482: u'learn',
#  483: u'leave',
#  484: u'leaves',
#  485: u'left',
#  486: u'lemon',
#  487: u'let',
#  488: u'level',
#  489: u'levels',
#  490: u'life',
#  491: u'light',
#  492: u'lightly',
#  493: u'like',
#  494: u'likely',
#  495: u'lime',
#  496: u'line',
#  497: u'link',
#  498: u'liquid',
#  499: u'list',
#  500: u'little',
#  501: u'live',
#  502: u'living',
#  503: u'll',
#  504: u'local',
#  505: u'london',
#  506: u'long',
#  507: u'longer',
#  508: u'look',
#  509: u'looking',
#  510: u'looks',
#  511: u'lose',
#  512: u'loss',
#  513: u'lost',
#  514: u'lot',
#  515: u'lots',
#  516: u'love',
#  517: u'low',
#  518: u'lower',
#  519: u'lunch',
#  520: u'magazine',
#  521: u'main',
#  522: u'major',
#  523: u'make',
#  524: u'makes',
#  525: u'making',
#  526: u'man',
#  527: u'march',
#  528: u'market',
#  529: u'matter',
#  530: u'maybe',
#  531: u'meal',
#  532: u'meals',
#  533: u'mean',
#  534: u'means',
#  535: u'meat',
#  536: u'media',
#  537: u'medical',
#  538: u'medicine',
#  539: u'medium',
#  540: u'melt',
#  541: u'melted',
#  542: u'memory',
#  543: u'men',
#  544: u'method',
#  545: u'microwave',
#  546: u'middle',
#  547: u'milk',
#  548: u'million',
#  549: u'mind',
#  550: u'mini',
#  551: u'minute',
#  552: u'minutes',
#  553: u'mix',
#  554: u'mixed',
#  555: u'mixer',
#  556: u'mixing',
#  557: u'mixture',
#  558: u'model',
#  559: u'models',
#  560: u'mom',
#  561: u'moment',
#  562: u'money',
#  563: u'month',
#  564: u'months',
#  565: u'morning',
#  566: u'mother',
#  567: u'muffin',
#  568: u'muscle',
#  569: u'muscles',
#  570: u'mushrooms',
#  571: u'music',
#  572: u'national',
#  573: u'natural',
#  574: u'need',
#  575: u'needed',
#  576: u'needs',
#  577: u'network',
#  578: u'new',
#  579: u'news',
#  580: u'nfl',
#  581: u'nice',
#  582: u'night',
#  583: u'non',
#  584: u'normal',
#  585: u'note',
#  586: u'november',
#  587: u'number',
#  588: u'nutella',
#  589: u'nutrition',
#  590: u'nuts',
#  591: u'october',
#  592: u'offer',
#  593: u'offers',
#  594: u'office',
#  595: u'oh',
#  596: u'oil',
#  597: u'old',
#  598: u'olive',
#  599: u'olympic',
#  600: u'olympics',
#  601: u'ones',
#  602: u'onion',
#  603: u'onions',
#  604: u'online',
#  605: u'open',
#  606: u'optional',
#  607: u'orange',
#  608: u'order',
#  609: u'organic',
#  610: u'original',
#  611: u'ounces',
#  612: u'outside',
#  613: u'oven',
#  614: u'oz',
#  615: u'package',
#  616: u'page',
#  617: u'pain',
#  618: u'pan',
#  619: u'paper',
#  620: u'parchment',
#  621: u'parents',
#  622: u'parmesan',
#  623: u'party',
#  624: u'past',
#  625: u'pasta',
#  626: u'pastry',
#  627: u'peanut',
#  628: u'people',
#  629: u'pepper',
#  630: u'peppers',
#  631: u'percent',
#  632: u'perfect',
#  633: u'person',
#  634: u'personal',
#  635: u'phone',
#  636: u'photo',
#  637: u'photography',
#  638: u'photos',
#  639: u'physical',
#  640: u'pick',
#  641: u'picture',
#  642: u'pictures',
#  643: u'pie',
#  644: u'piece',
#  645: u'pieces',
#  646: u'pink',
#  647: u'pizza',
#  648: u'place',
#  649: u'plan',
#  650: u'plastic',
#  651: u'plate',
#  652: u'play',
#  653: u'player',
#  654: u'plus',
#  655: u'pm',
#  656: u'point',
#  657: u'police',
#  658: u'pop',
#  659: u'popular',
#  660: u'pork',
#  661: u'position',
#  662: u'possible',
#  663: u'post',
#  664: u'posted',
#  665: u'posts',
#  666: u'pot',
#  667: u'potato',
#  668: u'potatoes',
#  669: u'pound',
#  670: u'pounds',
#  671: u'pour',
#  672: u'powder',
#  673: u'powdered',
#  674: u'power',
#  675: u'preheat',
#  676: u'prepare',
#  677: u'prepared',
#  678: u'press',
#  679: u'pressure',
#  680: u'pretty',
#  681: u'prevent',
#  682: u'print',
#  683: u'probably',
#  684: u'problem',
#  685: u'problems',
#  686: u'process',
#  687: u'processor',
#  688: u'produce',
#  689: u'product',
#  690: u'products',
#  691: u'program',
#  692: u'project',
#  693: u'protein',
#  694: u'provide',
#  695: u'public',
#  696: u'published',
#  697: u'pull',
#  698: u'pumpkin',
#  699: u'purpose',
#  700: u'quality',
#  701: u'question',
#  702: u'quick',
#  703: u'quickly',
#  704: u'quite',
#  705: u'rack',
#  706: u'raw',
#  707: u'read',
#  708: u'reading',
#  709: u'ready',
#  710: u'real',
#  711: u'really',
#  712: u'reason',
#  713: u'recent',
#  714: u'recently',
#  715: u'recipe',
#  716: u'recipes',
#  717: u'red',
#  718: u'reduce',
#  719: u'refrigerator',
#  720: u'regular',
#  721: u'related',
#  722: u'remaining',
#  723: u'remember',
#  724: u'remove',
#  725: u'repeat',
#  726: u'report',
#  727: u'research',
#  728: u'researchers',
#  729: u'rest',
#  730: u'restaurant',
#  731: u'result',
#  732: u'results',
#  733: u'return',
#  734: u'review',
#  735: u'rice',
#  736: u'rich',
#  737: u'right',
#  738: u'rise',
#  739: u'risk',
#  740: u'roasted',
#  741: u'roll',
#  742: u'rolls',
#  743: u'room',
#  744: u'round',
#  745: u'run',
#  746: u'running',
#  747: u'safe',
#  748: u'said',
#  749: u'salad',
#  750: u'salt',
#  751: u'san',
#  752: u'sandwich',
#  753: u'sauce',
#  754: u'saucepan',
#  755: u'save',
#  756: u'saw',
#  757: u'say',
#  758: u'says',
#  759: u'school',
#  760: u'science',
#  761: u'search',
#  762: u'season',
#  763: u'second',
#  764: u'seconds',
#  765: u'seeds',
#  766: u'seen',
#  767: u'self',
#  768: u'september',
#  769: u'serve',
#  770: u'served',
#  771: u'serving',
#  772: u'set',
#  773: u'sex',
#  774: u'shape',
#  775: u'share',
#  776: u'sheet',
#  777: u'shoes',
#  778: u'shop',
#  779: u'short',
#  780: u'shows',
#  781: u'shredded',
#  782: u'shrimp',
#  783: u'si',
#  784: u'sides',
#  785: u'sign',
#  786: u'similar',
#  787: u'simmer',
#  788: u'simple',
#  789: u'simply',
#  790: u'single',
#  791: u'sit',
#  792: u'site',
#  793: u'size',
#  794: u'skillet',
#  795: u'skin',
#  796: u'sleep',
#  797: u'slice',
#  798: u'sliced',
#  799: u'slices',
#  800: u'slightly',
#  801: u'slow',
#  802: u'slowly',
#  803: u'small',
#  804: u'smooth',
#  805: u'snack',
#  806: u'social',
#  807: u'soda',
#  808: u'soft',
#  809: u'soon',
#  810: u'soup',
#  811: u'sour',
#  812: u'source',
#  813: u'space',
#  814: u'special',
#  815: u'speed',
#  816: u'spend',
#  817: u'spice',
#  818: u'spinach',
#  819: u'spoon',
#  820: u'sport',
#  821: u'sports',
#  822: u'spray',
#  823: u'spread',
#  824: u'spring',
#  825: u'sprinkle',
#  826: u'stand',
#  827: u'star',
#  828: u'start',
#  829: u'started',
#  830: u'starting',
#  831: u'state',
#  832: u'states',
#  833: u'static',
#  834: u'stay',
#  835: u'steak',
#  836: u'step',
#  837: u'stick',
#  838: u'stir',
#  839: u'stirring',
#  840: u'stop',
#  841: u'store',
#  842: u'story',
#  843: u'straight',
#  844: u'strawberries',
#  845: u'strawberry',
#  846: u'street',
#  847: u'stress',
#  848: u'strong',
#  849: u'studies',
#  850: u'study',
#  851: u'stuff',
#  852: u'style',
#  853: u'sugar',
#  854: u'summer',
#  855: u'sun',
#  856: u'super',
#  857: u'support',
#  858: u'sure',
#  859: u'surface',
#  860: u'sweet',
#  861: u'swimsuit',
#  862: u'syrup',
#  863: u'table',
#  864: u'tablespoon',
#  865: u'tablespoons',
#  866: u'taken',
#  867: u'takes',
#  868: u'taking',
#  869: u'talk',
#  870: u'taste',
#  871: u'tasty',
#  872: u'tbsp',
#  873: u'tea',
#  874: u'team',
#  875: u'teaspoon',
#  876: u'teaspoons',
#  877: u'tech',
#  878: u'technology',
#  879: u'tell',
#  880: u'temperature',
#  881: u'tender',
#  882: u'term',
#  883: u'terminal01',
#  884: u'test',
#  885: u'text',
#  886: u'texture',
#  887: u'thank',
#  888: u'thanks',
#  889: u'thing',
#  890: u'things',
#  891: u'think',
#  892: u'thinking',
#  893: u'thought',
#  894: u'throw',
#  895: u'time',
#  896: u'times',
#  897: u'tip',
#  898: u'tips',
#  899: u'today',
#  900: u'told',
#  901: u'tomato',
#  902: u'tomatoes',
#  903: u'took',
#  904: u'topping',
#  905: u'toss',
#  906: u'total',
#  907: u'touch',
#  908: u'track',
#  909: u'traditional',
#  910: u'training',
#  911: u'transfer',
#  912: u'treat',
#  913: u'treatment',
#  914: u'tried',
#  915: u'true',
#  916: u'try',
#  917: u'trying',
#  918: u'tsp',
#  919: u'turkey',
#  920: u'turn',
#  921: u'turned',
#  922: u'tv',
#  923: u'twitter',
#  924: u'type',
#  925: u'types',
#  926: u'united',
#  927: u'university',
#  928: u'unsalted',
#  929: u'url',
#  930: u'use',
#  931: u'used',
#  932: u'user',
#  933: u'username',
#  934: u'users',
#  935: u'uses',
#  936: u'using',
#  937: u'usually',
#  938: u'vanilla',
#  939: u'var',
#  940: u'variety',
#  941: u've',
#  942: u'vegan',
#  943: u'vegetable',
#  944: u'vegetables',
#  945: u'vegetarian',
#  946: u'version',
#  947: u'video',
#  948: u'videos',
#  949: u'view',
#  950: u'vinegar',
#  951: u'vitamin',
#  952: u'wait',
#  953: u'want',
#  954: u'wanted',
#  955: u'warm',
#  956: u'wasn',
#  957: u'watch',
#  958: u'water',
#  959: u'way',
#  960: u'ways',
#  961: u'wear',
#  962: u'web',
#  963: u'website',
#  964: u'week',
#  965: u'weeks',
#  966: u'weight',
#  967: u'went',
#  968: u'wheat',
#  969: u'whipped',
#  970: u'whisk',
#  971: u'white',
#  972: u'whites',
#  973: u'wide',
#  974: u'width',
#  975: u'win',
#  976: u'wine',
#  977: u'winter',
#  978: u'woman',
#  979: u'women',
#  980: u'won',
#  981: u'wonderful',
#  982: u'words',
#  983: u'work',
#  984: u'working',
#  985: u'workout',
#  986: u'works',
#  987: u'world',
#  988: u'worth',
#  989: u'wrap',
#  990: u'wrong',
#  991: u'www',
#  992: u'year',
#  993: u'years',
#  994: u'yeast',
#  995: u'yellow',
#  996: u'yes',
#  997: u'yogurt',
#  998: u'york',
#  999: u'young'}

# %%
from gensim.models.ldamodel import LdaModel
from gensim.matutils import Sparse2Corpus
# First we convert our word-matrix into gensim's format
corpus = Sparse2Corpus(X, documents_columns = False)
# Then we fit an LDA model
lda_model = LdaModel(corpus=corpus, id2word=id2word, num_topics=15) #identify 15 different clusters of topics

# %%
#enumerate example
my_list = ['a','b','c','d']
for idx, element in enumerate(my_list):
    print idx, element
# Out:
# 0 a
# 1 b
# 2 c
# 3 d

# %%
num_topics = 15
num_words_per_topic = 5 #print 5 words with highest probability
for ti, topic in enumerate(lda_model.show_topics(num_topics = num_topics, num_words = num_words_per_topic)):
    print("Topic: %d" % (ti))
    print (topic)
    print()
# Out:
# Topic: 0
# (0, u'0.052*"chocolate" + 0.034*"peanut" + 0.030*"butter" + 0.013*"bars" + 0.013*"sugar"')
# ()
# Topic: 1
# (1, u'0.018*"health" + 0.013*"body" + 0.012*"people" + 0.010*"help" + 0.009*"time"')
# ()
# Topic: 2
# (2, u'0.043*"pizza" + 0.025*"background" + 0.023*"url" + 0.022*"height" + 0.022*"width"')
# ()
# Topic: 3
# (3, u'0.033*"flashvars" + 0.022*"sports" + 0.021*"com" + 0.021*"technology" + 0.018*"news"')
# ()
# Topic: 4
# (4, u'0.067*"com" + 0.066*"http" + 0.063*"www" + 0.035*"online" + 0.031*"image"')
# ()
# Topic: 5
# (5, u'0.020*"cup" + 0.014*"chocolate" + 0.014*"sugar" + 0.014*"butter" + 0.013*"baking"')
# ()
# Topic: 6
# (6, u'0.040*"food" + 0.020*"foods" + 0.017*"water" + 0.013*"hot" + 0.011*"meat"')
# ()
# Topic: 7
# (7, u'0.016*"recipe" + 0.015*"bacon" + 0.013*"make" + 0.011*"just" + 0.011*"like"')
# ()
# Topic: 8
# (8, u'0.023*"comment" + 0.021*"div" + 0.020*"ice" + 0.017*"cream" + 0.015*"just"')
# ()
# Topic: 9
# (9, u'0.037*"cancer" + 0.025*"bread" + 0.015*"breast" + 0.013*"food" + 0.013*"soda"')
# ()
# Topic: 10
# (10, u'0.021*"chicken" + 0.018*"cup" + 0.017*"cheese" + 0.016*"add" + 0.014*"sauce"')
# ()
# Topic: 11
# (11, u'0.037*"fashion" + 0.016*"like" + 0.015*"hair" + 0.015*"look" + 0.014*"style"')
# ()
# Topic: 12
# (12, u'0.023*"pan" + 0.022*"water" + 0.018*"heat" + 0.013*"eggs" + 0.012*"oven"')
# ()
# Topic: 13
# (13, u'0.011*"just" + 0.011*"like" + 0.010*"year" + 0.010*"said" + 0.009*"time"')
# ()
# Topic: 14
# (14, u'0.041*"food" + 0.039*"recipes" + 0.032*"raw" + 0.023*"recipe" + 0.012*"new"')
# ()

# %% [markdown]
# For example, about 5% probability "chocolate" is in Topic 0

# %%
# Unicode Handling
from __future__ import unicode_literals
import codecs

import numpy as np
import gensim

# spacy is used for pre-processing and traditional NLP
import spacy
from spacy.en import English

# Gensim is used for LDA and word2vec
from gensim.models.word2vec import Word2Vec

# %%
# Loading the tweet data
filename = '../dataset/captured-tweets.txt'
tweets = []
for tweet in codecs.open(filename, 'r', encoding="utf-8"):
    tweets.append(tweet)
# Setting up spacy
nlp_toolkit = English()

# %% [markdown]
# ## Exercise 1a
#
# Write a function that can take a take a sentence parsed by `spacy` and identify if it mentions a company named 'Google'. Remember, `spacy` can find entities and codes them as `ORG` if they are a company. Look at the slides for class 13 if you need a hint:
#
# ### Bonus (1b)
#
# Parameterize the company name so that the function works for any company.

# %%
def mentions_company(parsed):
    # Return True if the sentence contains an organization and that organization is Google
    for entity in parsed.ents:
        # Fill in code here
    # Otherwise return False
    return False

# 1b

def mentions_company(parsed, company='Google'):
    # Your code here
    pass

# %% [markdown]
# ## Exercise 1c
#
# Write a function that can take a sentence parsed by `spacy`
# and return the verbs of the sentence (preferably lemmatized)

# %%
def get_actions(parsed):
    actions = []
    # Your code here
    return actions

# %% [markdown]
# ## Exercise 1d
# For each tweet, parse it using spacy and print it out if the tweet has 'release' or 'announce' as a verb. You'll need to use your `mentions_company` and `get_actions` functions.

# %%
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    pass

# %% [markdown]
# ## Exercise 1e
# Write a function that identifies countries - HINT: the entity label for countries is GPE (or GeoPolitical Entity)

# %%
def mentions_country(parsed, country):
    pass

# %% [markdown]
# ## Exercise 1f
#
# Re-run (d) to find country tweets that discuss 'Iran' announcing or releasing.

# %%
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    pass

# %% [markdown]
# ## Exercise 2
# Build a `word2vec` model of the tweets we have collected using `gensim`.
#
# ### Exercise 2a:
# First take the collection of tweets and tokenize them using spacy.
#
# * Think about how this should be done.
# * Should you only use upper-case or lower-case?
# * Should you remove punctuations or symbols?

# %%
text_split = [[x.text if x.pos != spacy.parts_of_speech.VERB else x.lemma_ 
                for x in nlp_toolkit(t)] for t in tweets]

# %% [markdown]
# ### Exercise 2b:
# Build a `word2vec` model.
# Test the window size as well - this is how many surrounding words need to be used to model a word. What do you think is appropriate for Twitter?

# %%
model = Word2Vec(text_split, size=100, window=4, min_count=5, workers=4)

# %% [markdown]
# ### Exercise 2c:
# Test your word2vec model with a few similarity functions.
# * Find words similar to 'Syria'.
# * Find words similar to 'war'.
# * Find words similar to "Iran".
# * Find words similar to 'Verizon'.

# %%
model.most_similar(positive=['Syria'])

# %% [markdown]
# # Exercise 2d
#
# Adjust the choices / parameters in (b) and (c) as necessary.

# %% [markdown]
# ## Exercise 3
#
# Filter tweets to those that mention 'Iran' or similar entities and 'war' or similar entities.
# * Do this using just spacy.
# * Do this using word2vec similarity scores.

# %%
# Using spacy
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    pass

# %%
# Using word2vec similarity scores
for tweet in tweets[:200]:
    parsed = nlp_toolkit(tweet)
    pass
